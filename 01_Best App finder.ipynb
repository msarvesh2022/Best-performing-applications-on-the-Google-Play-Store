# %% [markdown]
# In this innovative machine project, I meticulously developed a robust machine learning solution aimed at identifying the optimal Google Play Store applications based on a set of crucial features. Here's a concise overview of the project:

# %% [markdown]
# ### Objective: This project focused on leveraging advanced machine learning techniques to determine the best-performing applications on the Google Play Store. The primary criteria for evaluation included factors like user ratings, installation count, reviews, and application category.
#
#
#
#
# #### Key Feautures
#
#
#
# - Technological Framework: Employing the power of Python, I orchestrated the project using key libraries and tools. Pandas facilitated seamless data manipulation and preprocessing, ensuring the dataset was primed for analysis. The scikit-learn (sklearn) library became pivotal in implementing a K-means clustering algorithm, enabling the classification of applications into distinct groups based on their feature similarities.
#
# - Data Processing: With Python and Pandas, I meticulously cleansed and organized the data. This involved handling missing values, transforming categorical variables, and ensuring data consistency. The resulting dataset formed the foundation for subsequent analysis.
#
# - K-means Clustering: Utilizing the sklearn library, I implemented the K-means clustering algorithm. By applying this unsupervised learning technique, I partitioned the applications into clusters based on shared characteristics, allowing for more insightful differentiation and evaluation.
#
# - Insights and Recommendations: Through the implementation of K-means, I gained valuable insights into the diverse groups of applications within the Play Store. This knowledge empowered me to provide data-driven recommendations to users and stakeholders, highlighting the applications that excelled in various categories, thus optimizing their selection process.

# %% [markdown]
# In summary, This machine learning project harnessed the capabilities of Python, Pandas, and sklearn's K-means clustering to decipher the optimal Google Play Store applications. By analyzing features such as ratings, installations, reviews, and categories, I equipped users with a powerful tool for making informed decisions within the ever-expanding realm of mobile applications.

# %% [markdown]
# Date - 04-08-2023
#
# data source- Kaggle

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df= pd.read_csv('googleplaystore.csv.zip')

# %%
df_initial= pd.read_csv('googleplaystore.csv.zip')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ### Final Dataset by Machine Learning alorithms

# %%
final_application
# Out:
#     Rank  app_id                                              App
# 0      1     193                                          Hay Day
# 1      2     808                                       Boom Beach
# 2      3     817                                         Township
# 3      4     995                                  SimCity BuildIt
# 4      5     230                                Talking Tom Cat 2
# 5      6     874                              Bubble Witch 2 Saga
# 6      7     404                             Angry Birds Epic RPG
# 7      8    1200                              MARVEL Future Fight
# 8      9     169                                        Minecraft
# 9     10     759                    Bitmoji – Your Personal Emoji
# 10    11    1020    Clash of Kings : The King Of Fighters version
# 11    12     182                      The Tribez: Build a Village
# 12    13     252                                  Talking Tom Cat
# ...

# %% [markdown]
# .
#
#
#
#
#
#
# .
#
#
#
#
#
#
# .

# %% [markdown]
# # Start

# %% [markdown]
# ### (i) Basic Information about Dataset

# %%
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.isnull().mean()*100
# Out:
# App                0.000000
# Category           0.000000
# Rating            13.596532
# Reviews            0.000000
# Size               0.000000
# Installs           0.000000
# Type               0.009224
# Price              0.000000
# Content Rating     0.009224
# Genres             0.000000
# Last Updated       0.000000
# Current Ver        0.073794
# Android Ver        0.027673
# dtype: float64

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.shape
# Out:
# (10841, 13)

# %%
df= df.drop_duplicates()

# %%
df.shape
# Out:
# (10358, 13)

# %% [markdown]
# ### (ii) Removing the duplicates

# %%
df= df.drop_duplicates(subset='App')

# %%
df.shape
# Out:
# (9660, 13)

# %%
df.App.value_counts()
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook    1
# CK Pharmacies                                     1
# CK Call NEW                                       1
# Ck Coif                                           1
# CONTRACT KILLER: ZOMBIES                          1
#                                                  ..
# Bike Race Free - Top Motorcycle Racing Games      1
# Dance School Stories - Dance Dreams Come True     1
# 3D Bowling                                        1
# Mind Games Pro                                    1
# iHoroscope - 2018 Daily Horoscope & Astrology     1
# Name: count, Length: 9660, dtype: int64

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df = df.reset_index(drop=True)

# %%
df.tail()
# Out:
#                                                 App             Category  \
# 9655                               Sya9a Maroc - FR               FAMILY
# 9656               Fr. Mike Schmitz Audio Teachings               FAMILY
# 9657                         Parkinson Exercices FR              MEDICAL
# 9658                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9659  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating Reviews                Size     Installs  Type Price  \
# 9655     4.5      38                 53M       5,000+  Free     0
# 9656     5.0       4                3.6M         100+  Free     0
# 9657     NaN       3                9.5M       1,000+  Free     0
# 9658     4.5     114  Varies with device       1,000+  Free     0
# 9659     4.5  398307                 19M  10,000,000+  Free     0
#
#      Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.head(2
       )
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %% [markdown]
# ### (iii) Data Cleaning and Feature Engineering

# %% [markdown]
# ### Category column

# %%
df.Category.value_counts()
# Out:
# Category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# ART_AND_DESIGN           64
# EVENTS                   64
# PARENTING                60
# COMICS                   56
# ...

# %%
df.Category.nunique()
# Out:
# 34

# %%
df[df.Category=='1.9']
# Out:
#                                           App Category  Rating Reviews  \
# 9300  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9300  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9300       1.0.19  4.0 and up         NaN

# %%
df = df.drop(9300)

# %%
df.tail(2)
# Out:
#                                                 App             Category  \
# 9658                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9659  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating Reviews                Size     Installs  Type Price  \
# 9658     4.5     114  Varies with device       1,000+  Free     0
# 9659     4.5  398307                 19M  10,000,000+  Free     0
#
#      Content Rating             Genres      Last Updated         Current Ver  \
# 9658     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 9659       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#              Android Ver
# 9658  Varies with device
# 9659  Varies with device

# %%
df.shape
# Out:
# (9659, 13)

# %%
df = df.reset_index(drop= True)

# %%
df.tail(2)
# Out:
#                                                 App             Category  \
# 9657                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9658  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating Reviews                Size     Installs  Type Price  \
# 9657     4.5     114  Varies with device       1,000+  Free     0
# 9658     4.5  398307                 19M  10,000,000+  Free     0
#
#      Content Rating             Genres      Last Updated         Current Ver  \
# 9657     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 9658       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#              Android Ver
# 9657  Varies with device
# 9658  Varies with device

# %%
df.shape
# Out:
# (9659, 13)

# %%
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
df.Category.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
df.Category.value_counts()
# Out:
# Category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           64
# PARENTING                60
# COMICS                   56
# ...

# %%
game_df= df[df.Category=='GAME']

# %%
game_df.head(3)
# Out:
#                    App Category  Rating   Reviews Size        Installs  Type  \
# 1355            ROBLOX     GAME     4.5   4447388  67M    100,000,000+  Free
# 1356    Subway Surfers     GAME     4.5  27722264  76M  1,000,000,000+  Free
# 1357  Candy Crush Saga     GAME     4.4  22426677  74M    500,000,000+  Free
#
#      Price Content Rating                        Genres   Last Updated  \
# 1355     0   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1356     0   Everyone 10+                        Arcade  July 12, 2018
# 1357     0       Everyone                        Casual   July 5, 2018
#
#        Current Ver Android Ver
# 1355  2.347.225742  4.1 and up
# 1356        1.90.0  4.1 and up
# 1357     1.129.0.2  4.1 and up

# %%
game_df.shape
# Out:
# (959, 13)

# %%
df.Category.nunique()
# Out:
# 33

# %%
df1= df.copy()

# %% [markdown]
# ## > Rating

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df.Rating.dtype
# Out:
# dtype('float64')

# %%
df.Rating.value_counts().head(10)
# Out:
# Rating
# 4.3    897
# 4.4    895
# 4.5    848
# 4.2    810
# 4.6    683
# 4.1    621
# 4.0    513
# 4.7    442
# 3.9    359
# 3.8    286
# Name: count, dtype: int64

# %%
df.sort_values(by='Rating', ascending=False)
# Out:
#                                             App             Category  Rating  \
# 4703         Jobs in Canada - Emplois au Canada             BUSINESS     5.0
# 6120                             CD CHOICE TUBE               FAMILY     5.0
# 6151                                   CE Smart                TOOLS     5.0
# 6160  TI-84 CE Graphing Calculator Manual TI 84               FAMILY     5.0
# 8220                                   EG India            LIFESTYLE     5.0
# ...                                         ...                  ...     ...
# 9642                                  Cardio-FR              MEDICAL     NaN
# 9643                         Naruto & Boruto FR               SOCIAL     NaN
# 9649                   payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 9653                                   FR Forms             BUSINESS     NaN
# 9656                     Parkinson Exercices FR              MEDICAL     NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df.Rating.describe()
# Out:
# count    8196.000000
# mean        4.173243
# std         0.536625
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %% [markdown]
# #### Data distribution of Rating feature

# %%
sns.displot(df.Rating)

# %%
game_df.Rating.mode()
# Out:
# 0    4.3
# Name: Rating, dtype: float64

# %%
df['Rating']= df['Rating'].fillna(4.17)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
df.Rating.describe()
# Out:
# count    9659.000000
# mean        4.172752
# std         0.494314
# min         1.000000
# 25%         4.000000
# 50%         4.200000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %% [markdown]
# ### Dropping all null value

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %% [markdown]
# ### Reviews

# %%
df.Reviews.dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Reviews'] = df['Reviews'].astype('int32')

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.Reviews.describe()
# Out:
# count    9.648000e+03
# mean     2.168369e+05
# std      1.832349e+06
# min      0.000000e+00
# 25%      2.500000e+01
# 50%      9.690000e+02
# 75%      2.944925e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
df.sort_values(by='Reviews',ascending=False)
# Out:
#                                            App        Category  Rating  \
# 2002                                  Facebook          SOCIAL    4.10
# 300                         WhatsApp Messenger   COMMUNICATION    4.40
# 2003                                 Instagram          SOCIAL    4.50
# 299   Messenger – Text and Video Chat for Free   COMMUNICATION    4.00
# 1372                            Clash of Clans            GAME    4.60
# ...                                        ...             ...     ...
# 7754                    Test Application DT 02  ART_AND_DESIGN    4.17
# 4183                               Woodland AH         MEDICAL    4.17
# 8132                                     EC QR    PRODUCTIVITY    4.17
# 7003                     Hyundai CX Conference   COMMUNICATION    4.17
# 4160                         Ag Across America          FAMILY    4.17
#
#        Reviews                Size        Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# ### Noted !! because here is 0 reviews also.

# %%
df[df.Reviews==0]
# Out:
#                                                   App            Category  \
# 408                                 Truth or Dare Pro              DATING
# 409   Private Dating, Hide App- Blue for PrivacyHider              DATING
# 520                                Dating White Girls              DATING
# 522                                      Geeks Dating              DATING
# 526                                CAM5678 Video Chat              DATING
# ...                                               ...                 ...
# 9591                                         FQ India           LIFESTYLE
# 9592                                          Miss FQ  NEWS_AND_MAGAZINES
# 9616                             Word Search Tab 1 FR              FAMILY
# 9640                                        PLMGSS FR        PRODUCTIVITY
# 9653                                         FR Forms            BUSINESS
#
#       Rating  Reviews   Size Installs  Type  Price Content Rating  \
# ...

# %%
df.Genres.nunique()
# Out:
# 118

# %%
df.Category.nunique()
# Out:
# 33

# %% [markdown]
# ### Size

# %%
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Size    Installs  Type Price Content Rating  \
# 0      159   19M     10,000+  Free     0       Everyone
# 1      967   14M    500,000+  Free     0       Everyone
# 2    87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
df.Size.value_counts()
# Out:
# Size
# Varies with device    1226
# 12M                    181
# 11M                    181
# 13M                    177
# 14M                    176
#                       ...
# 721k                     1
# 430k                     1
# 429k                     1
# 200k                     1
# 619k                     1
# Name: count, Length: 457, dtype: int64

# %%
df.Installs.dtype
# Out:
# dtype('O')

# %%
df['Installs'] = df['Installs'].astype('str')

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.Type.value_counts()
# Out:
# Type
# Free    8895
# Paid     753
# Name: count, dtype: int64

# %%
df.Price.value_counts()
# Out:
# Price
# 0          8895
# $0.99       143
# $2.99       124
# $1.99        73
# $4.99        70
#            ...
# $18.99        1
# $389.99       1
# $19.90        1
# $1.75         1
# $1.04         1
# Name: count, Length: 92, dtype: int64

# %% [markdown]
# ### (iv) Renaming the column name

# %%
df.rename(columns={'Content Rating':'content_rating','Last Updated':'last_updated',
                   'Current Ver':'current_ver',
                   'Android Ver':'android_ver'},inplace=True)

# %%
df.columns[2]
# Out:
# 'Rating'

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'content_rating', 'Genres', 'last_updated', 'current_ver',
#        'android_ver'],
#       dtype='object')

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Installs  Type Price content_rating  \
# 0      159  19M   10,000+  Free     0       Everyone
# 1      967  14M  500,000+  Free     0       Everyone
#
#                       Genres      last_updated current_ver   android_ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %% [markdown]
# ## Installs

# %%
df.Installs.dtype
# Out:
# dtype('O')

# %%
df.sort_values(by='Installs',ascending=False)
# Out:
#                                                App            Category  \
# 2527                    SHAREit - Transfer & Share               TOOLS
# 2008                                      Snapchat              SOCIAL
# 2004                                 Facebook Lite              SOCIAL
# 1410                                My Talking Tom                GAME
# 357                    LINE: Free Calls & Messages       COMMUNICATION
# ...                                            ...                 ...
# 7519                             Sweden Newspapers  NEWS_AND_MAGAZINES
# 3561  Popsicle Launcher for Android P 9.0 launcher     PERSONALIZATION
# 8751                                   Eu sou Rico             FINANCE
# 5661                                 cronometra-br        PRODUCTIVITY
# 4956                    Ain Arabic Kids Alif Ba ta              FAMILY
#
#       Rating   Reviews                Size      Installs  Type    Price  \
# ...

# %%
df[df.Installs=="0+"]
# Out:
#                                                App            Category  \
# 3561  Popsicle Launcher for Android P 9.0 launcher     PERSONALIZATION
# 4352                       Ak Parti Yardım Toplama              SOCIAL
# 4522                        AP Series Solution Pro              FAMILY
# 4956                    Ain Arabic Kids Alif Ba ta              FAMILY
# 5661                                 cronometra-br        PRODUCTIVITY
# 6387                                 Pekalongan CJ              SOCIAL
# 7016                                    CX Network            BUSINESS
# 7519                             Sweden Newspapers  NEWS_AND_MAGAZINES
# 7754                        Test Application DT 02      ART_AND_DESIGN
# 8216                      EG | Explore Folegandros    TRAVEL_AND_LOCAL
# 8577                                  EP Cook Book             MEDICAL
# 8751                                   Eu sou Rico             FINANCE
# ...

# %%
a= '150+'

# %%
a.replace('+',"")
# Out:
# '150'

# %%
df['total_instaall'] = df.Installs.apply(lambda x:x.replace("+",""))

# %%
df['total_install'] = df.total_instaall.apply(lambda x:x.replace(",",""))

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price content_rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      last_updated         current_ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['total_install']= df.total_install.astype('int32')

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Installs  Type Price content_rating  \
# 0      159  19M   10,000+  Free     0       Everyone
# 1      967  14M  500,000+  Free     0       Everyone
#
#                       Genres      last_updated current_ver   android_ver  \
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
#
#   total_instaall  total_install
# 0         10,000          10000
# 1        500,000         500000

# %% [markdown]
# ### (v)  Droping unnecessary columns

# %%
df.drop(columns=['Installs','total_instaall'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Type Price content_rating                     Genres  \
# 0      159   19M  Free     0       Everyone               Art & Design
# 1      967   14M  Free     0       Everyone  Art & Design;Pretend Play
# 2    87510  8.7M  Free     0       Everyone               Art & Design
# 3   215644   25M  Free     0           Teen               Art & Design
# 4      967  2.8M  Free     0       Everyone    Art & Design;Creativity
#
#        last_updated         current_ver   android_ver  total_install
# ...

# %% [markdown]
# ## >Last updated

# %%
df['last_updated'] = df.last_updated.apply(lambda x: x.replace(",",""))

# %%
df.iloc[1
       ]
# Out:
# App                     Coloring book moana
# Category                     ART_AND_DESIGN
# Rating                                  3.9
# Reviews                                 967
# Size                                    14M
# Type                                   Free
# Price                                     0
# content_rating                     Everyone
# Genres            Art & Design;Pretend Play
# last_updated                January 15 2018
# current_ver                           2.0.0
# android_ver                    4.0.3 and up
# total_install                        500000
# Name: 1, dtype: object

# %%
df['last_updated'] = df.last_updated.apply(lambda x : " ".join(x.split()[2:3]))

# %%
df.iloc[1]
# Out:
# App                     Coloring book moana
# Category                     ART_AND_DESIGN
# Rating                                  3.9
# Reviews                                 967
# Size                                    14M
# Type                                   Free
# Price                                     0
# content_rating                     Everyone
# Genres            Art & Design;Pretend Play
# last_updated                           2018
# current_ver                           2.0.0
# android_ver                    4.0.3 and up
# total_install                        500000
# Name: 1, dtype: object

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Type Price content_rating                     Genres  \
# 0      159  19M  Free     0       Everyone               Art & Design
# 1      967  14M  Free     0       Everyone  Art & Design;Pretend Play
#
#   last_updated current_ver   android_ver  total_install
# 0         2018       1.0.0  4.0.3 and up          10000
# 1         2018       2.0.0  4.0.3 and up         500000

# %%
df.last_updated.value_counts()
# Out:
# last_updated
# 2018    6279
# 2017    1791
# 2016     777
# 2015     449
# 2014     203
# 2013     107
# 2012      26
# 2011      15
# 2010       1
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Type Price content_rating                     Genres  \
# 0      159  19M  Free     0       Everyone               Art & Design
# 1      967  14M  Free     0       Everyone  Art & Design;Pretend Play
#
#   last_updated current_ver   android_ver  total_install
# 0         2018       1.0.0  4.0.3 and up          10000
# 1         2018       2.0.0  4.0.3 and up         500000

# %%
df1.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df2= df.copy()

# %%
df.Genres.nunique()
# Out:
# 118

# %% [markdown]
# ### droping this columns because we have already category column which is defined the different genres of App

# %%
df.drop(columns=['Genres',], axis= 1, inplace=True)

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Type', 'Price',
#        'content_rating', 'last_updated', 'current_ver', 'android_ver',
#        'total_install'],
#       dtype='object')

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Type Price content_rating last_updated current_ver  \
# 0      159  19M  Free     0       Everyone         2018       1.0.0
# 1      967  14M  Free     0       Everyone         2018       2.0.0
#
#     android_ver  total_install
# 0  4.0.3 and up          10000
# 1  4.0.3 and up         500000

# %% [markdown]
# ## Cureent_version

# %%
df.current_ver.nunique()
# Out:
# 2817

# %%
df.drop(columns=['current_ver'], axis= 1, inplace=True)

# %%
df.android_ver.nunique()
# Out:
# 33

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Type Price content_rating last_updated   android_ver  \
# 0      159  19M  Free     0       Everyone         2018  4.0.3 and up
# 1      967  14M  Free     0       Everyone         2018  4.0.3 and up
#
#    total_install
# 0          10000
# 1         500000

# %% [markdown]
# ## content rating

# %%
df.content_rating.nunique()
# Out:
# 6

# %%
df.content_rating.value_counts()
# Out:
# content_rating
# Everyone           7893
# Teen               1036
# Mature 17+          393
# Everyone 10+        321
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
def content_filt(age):
    if age == 'Mature 17+' or age == 'Everyone 10+':
        return 'Teen'
    else:
        return age

# %%
df['rating_age'] = df.content_rating.apply(content_filt)

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Type Price content_rating last_updated   android_ver  \
# 0      159  19M  Free     0       Everyone         2018  4.0.3 and up
# 1      967  14M  Free     0       Everyone         2018  4.0.3 and up
#
#    total_install rating_age
# 0          10000   Everyone
# 1         500000   Everyone

# %%
df.rating_age.value_counts()
# Out:
# rating_age
# Everyone           7893
# Teen               1750
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
df.drop(columns=['content_rating'], axis =1 , inplace=True)

# %% [markdown]
# ## Price

# %%
df.Price.value_counts()
# Out:
# Price
# 0          8895
# $0.99       143
# $2.99       124
# $1.99        73
# $4.99        70
#            ...
# $18.99        1
# $389.99       1
# $19.90        1
# $1.75         1
# $1.04         1
# Name: count, Length: 92, dtype: int64

# %%
df['Price_in_dollar'] = df.Price.apply(lambda x: x.replace('$',''))

# %%
df.drop(columns=['Price'], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Type last_updated   android_ver  total_install rating_age  \
# 0      159  19M  Free         2018  4.0.3 and up          10000   Everyone
# 1      967  14M  Free         2018  4.0.3 and up         500000   Everyone
#
#   Price_in_dollar
# 0               0
# 1               0

# %%
df.iloc[[229,170]]
# Out:
#                                 App             Category  Rating  Reviews  \
# 230  Tiny Scanner - PDF Scanner App             BUSINESS     4.7   286897
# 171              All Maths Formulas  BOOKS_AND_REFERENCE     4.4     2709
#
#      Size  Type last_updated android_ver  total_install rating_age  \
# 230   39M  Free         2017  3.0 and up       10000000   Everyone
# 171  6.8M  Free         2018  4.4 and up        1000000   Everyone
#
#     Price_in_dollar
# 230               0
# 171               0

# %%
df['Price_in_dollar']= df.Price_in_dollar.astype('float')

# %%
df.Price_in_dollar.dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int32
# Size                object
# Type                object
# last_updated        object
# android_ver         object
# total_install        int32
# rating_age          object
# Price_in_dollar    float64
# dtype: object

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Type last_updated   android_ver  total_install rating_age  \
# 0      159  19M  Free         2018  4.0.3 and up          10000   Everyone
# 1      967  14M  Free         2018  4.0.3 and up         500000   Everyone
#
#    Price_in_dollar
# 0              0.0
# 1              0.0

# %%
df[df.App=='Facebook']
# Out:
#            App Category  Rating   Reviews                Size  Type  \
# 2002  Facebook   SOCIAL     4.1  78158306  Varies with device  Free
#
#      last_updated         android_ver  total_install rating_age  \
# 2002         2018  Varies with device     1000000000       Teen
#
#       Price_in_dollar
# 2002              0.0

# %%
df.Size.nunique()
# Out:
# 457

# %%
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Size  Type last_updated   android_ver  total_install rating_age  \
# 0      159   19M  Free         2018  4.0.3 and up          10000   Everyone
# 1      967   14M  Free         2018  4.0.3 and up         500000   Everyone
# 2    87510  8.7M  Free         2018  4.0.3 and up        5000000   Everyone
#
#    Price_in_dollar
# 0              0.0
# 1              0.0
# 2              0.0

# %%
df3= df.copy()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Type last_updated   android_ver  total_install rating_age  \
# 0      159   19M  Free         2018  4.0.3 and up          10000   Everyone
# 1      967   14M  Free         2018  4.0.3 and up         500000   Everyone
# 2    87510  8.7M  Free         2018  4.0.3 and up        5000000   Everyone
# 3   215644   25M  Free         2018    4.2 and up       50000000       Teen
# 4      967  2.8M  Free         2018    4.4 and up         100000   Everyone
#
#    Price_in_dollar
# 0              0.0
# ...

# %% [markdown]
# # Done with Data Cleaning !!

# %%
import seaborn as sns

# %%
sns.boxplot(df.Rating)
# Out:
# <Axes: >

# %%
df.select_dtypes(exclude=object)
# Out:
#       Rating  Reviews  total_install  Price_in_dollar
# 0       4.10      159          10000              0.0
# 1       3.90      967         500000              0.0
# 2       4.70    87510        5000000              0.0
# 3       4.50   215644       50000000              0.0
# 4       4.30      967         100000              0.0
# ...      ...      ...            ...              ...
# 9654    4.50       38           5000              0.0
# 9655    5.00        4            100              0.0
# 9656    4.17        3           1000              0.0
# 9657    4.50      114           1000              0.0
# 9658    4.50   398307       10000000              0.0
#
# [9648 rows x 4 columns]

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Type last_updated   android_ver  total_install rating_age  \
# 0      159   19M  Free         2018  4.0.3 and up          10000   Everyone
# 1      967   14M  Free         2018  4.0.3 and up         500000   Everyone
# 2    87510  8.7M  Free         2018  4.0.3 and up        5000000   Everyone
# 3   215644   25M  Free         2018    4.2 and up       50000000       Teen
# 4      967  2.8M  Free         2018    4.4 and up         100000   Everyone
#
#    Price_in_dollar
# 0              0.0
# ...

# %%
df.Size.value_counts()
# Out:
# Size
# Varies with device    1226
# 12M                    181
# 11M                    181
# 13M                    177
# 14M                    176
#                       ...
# 721k                     1
# 430k                     1
# 429k                     1
# 200k                     1
# 619k                     1
# Name: count, Length: 457, dtype: int64

# %% [markdown]
# ### there is some doubt in size column so I am going to drop it.

# %%
df.drop('Size', axis =1 ,inplace=True)

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Type last_updated   android_ver  total_install rating_age  \
# 0      159  Free         2018  4.0.3 and up          10000   Everyone
# 1      967  Free         2018  4.0.3 and up         500000   Everyone
#
#    Price_in_dollar
# 0              0.0
# 1              0.0

# %%
a= "2.3.4 and up"

# %%
type(a)
# Out:
# str

# %%
"2.3" in a
# Out:
# True

# %%
def find(version):
    if "2." in version:
        return "2.0"
    elif "3.0" in version:
        return "3.0"
    elif "4.0" in version:
        return "4.0"
    else :
        return version

# %%
df['latest_version'] = df['android_ver'].apply(find)

# %%
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Type last_updated   android_ver  total_install rating_age  \
# 0      159  Free         2018  4.0.3 and up          10000   Everyone
# 1      967  Free         2018  4.0.3 and up         500000   Everyone
# 2    87510  Free         2018  4.0.3 and up        5000000   Everyone
#
#    Price_in_dollar latest_version
# 0              0.0            4.0
# 1              0.0            4.0
# 2              0.0            4.0

# %%
df.latest_version.nunique()
# Out:
# 25

# %%
df.android_ver.nunique()
# Out:
# 33

# %%
df.latest_version.value_counts()
# Out:
# latest_version
# 4.0                   2680
# 4.1 and up            2202
# 2.0                   1299
# Varies with device     989
# 4.4 and up             818
# 5.0 and up             512
# 4.2 and up             371
# 3.0                    230
# 4.3 and up             221
# 1.6 and up             115
# 6.0 and up              54
# 7.0 and up              42
# 3.2 and up              36
# 5.1 and up              22
# 1.5 and up              19
# 4.4W and up             11
# 3.1 and up              10
# 8.0 and up               6
# 7.1 and up               3
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 5.0 - 7.1.1              1
# Name: count, dtype: int64

# %%
df.android_ver.dtype
# Out:
# dtype('O')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Type last_updated   android_ver  total_install rating_age  \
# 0      159  Free         2018  4.0.3 and up          10000   Everyone
# 1      967  Free         2018  4.0.3 and up         500000   Everyone
# 2    87510  Free         2018  4.0.3 and up        5000000   Everyone
# 3   215644  Free         2018    4.2 and up       50000000       Teen
# 4      967  Free         2018    4.4 and up         100000   Everyone
#
#    Price_in_dollar latest_version
# 0              0.0            4.0
# ...

# %%
df3.shape
# Out:
# (9648, 11)

# %%
df.drop(columns=['android_ver','latest_version'], axis =1 , inplace=True)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Type last_updated  total_install rating_age  Price_in_dollar
# 0      159  Free         2018          10000   Everyone              0.0
# 1      967  Free         2018         500000   Everyone              0.0
# 2    87510  Free         2018        5000000   Everyone              0.0
# 3   215644  Free         2018       50000000       Teen              0.0
# 4      967  Free         2018         100000   Everyone              0.0

# %%
df.Category.value_counts()
# Out:
# Category
# FAMILY                 1828
# GAME                    959
# TOOLS                   825
# BUSINESS                420
# MEDICAL                 395
# PRODUCTIVITY            374
# PERSONALIZATION         374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     221
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       83
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           63
# PARENTING                60
# COMICS                   56
# ...

# %% [markdown]
# ### >> inserting new column named 'rating mass' with the help of "Rating" and "Reviews"

# %%
df['rating_mass']= round(df['Rating']*df['Reviews'],2)

# %%
df.Category.value_counts()
# Out:
# Category
# FAMILY                 1828
# GAME                    959
# TOOLS                   825
# BUSINESS                420
# MEDICAL                 395
# PRODUCTIVITY            374
# PERSONALIZATION         374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     221
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       83
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           63
# PARENTING                60
# COMICS                   56
# ...

# %% [markdown]
# ## (vi) now we have to break down whole dataframe into different category !!

# %%
family_df= df[df.Category=='FAMILY']

# %%
family_df.shape
# Out:
# (1828, 10)

# %%
family_df.head()
# Out:
#                                                     App Category  Rating  \
# 1575                       Jewels Crush- Match 3 Puzzle   FAMILY     4.4
# 1576                                   Coloring & Learn   FAMILY     4.4
# 1577                                            Mahjong   FAMILY     4.5
# 1578  Super ABC! Learning games for kids! Preschool ...   FAMILY     4.6
# 1579                                      Toy Pop Cubes   FAMILY     4.5
#
#       Reviews  Type last_updated  total_install rating_age  Price_in_dollar  \
# 1575    14774  Free         2018        1000000   Everyone              0.0
# 1576    12753  Free         2018        5000000   Everyone              0.0
# 1577    33983  Free         2018        5000000   Everyone              0.0
# 1578    20267  Free         2018        1000000   Everyone              0.0
# 1579     5761  Free         2018        1000000   Everyone              0.0
#
#       rating_mass
# 1575      65005.6
# 1576      56113.2
# ...

# %%
family_df.reset_index(drop='keep', inplace=True)

# %%
family_df.tail(2)
# Out:
#                                    App Category  Rating  Reviews  Type  \
# 1826                  Sya9a Maroc - FR   FAMILY     4.5       38  Free
# 1827  Fr. Mike Schmitz Audio Teachings   FAMILY     5.0        4  Free
#
#      last_updated  total_install rating_age  Price_in_dollar  rating_mass
# 1826         2017           5000   Everyone              0.0        171.0
# 1827         2018            100   Everyone              0.0         20.0

# %%
family_df.drop('Category', axis =1 , inplace=True)
# Out:
# C:\Users\as\AppData\Local\Temp\ipykernel_8492\1959971083.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   family_df.drop('Category', axis =1 , inplace=True)

# %%
family_df.head()
# Out:
#                                                  App  Rating  Reviews  Type  \
# 0                       Jewels Crush- Match 3 Puzzle     4.4    14774  Free
# 1                                   Coloring & Learn     4.4    12753  Free
# 2                                            Mahjong     4.5    33983  Free
# 3  Super ABC! Learning games for kids! Preschool ...     4.6    20267  Free
# 4                                      Toy Pop Cubes     4.5     5761  Free
#
#   last_updated  total_install rating_age  Price_in_dollar  rating_mass
# 0         2018        1000000   Everyone              0.0      65005.6
# 1         2018        5000000   Everyone              0.0      56113.2
# 2         2018        5000000   Everyone              0.0     152923.5
# 3         2018        1000000   Everyone              0.0      93228.2
# 4         2018        1000000   Everyone              0.0      25924.5

# %%
a=family_df.sort_values(by='rating_mass', ascending=False)

# %%
a.head(5)
# Out:
#                    App  Rating   Reviews  Type last_updated  total_install  \
# 192            Hay Day     4.5  10053186  Free         2018      100000000
# 807         Boom Beach     4.5   5591653  Free         2018       50000000
# 816           Township     4.6   4451317  Free         2018       50000000
# 994    SimCity BuildIt     4.5   4218587  Free         2018       50000000
# 229  Talking Tom Cat 2     4.3   3213548  Free         2018      100000000
#
#     rating_age  Price_in_dollar  rating_mass
# 192   Everyone              0.0   45239337.0
# 807       Teen              0.0   25162438.5
# 816   Everyone              0.0   20476058.2
# 994       Teen              0.0   18983641.5
# 229       Teen              0.0   13818256.4

# %%
final_family_df=a[['App','rating_mass']]

# %%
final_family_df.head(5)
# Out:
#                    App  rating_mass
# 192            Hay Day   45239337.0
# 807         Boom Beach   25162438.5
# 816           Township   20476058.2
# 994    SimCity BuildIt   18983641.5
# 229  Talking Tom Cat 2   13818256.4

# %% [markdown]
# ### according to my analysis these are the top 5 App in "family" category.
#
# - Hay Day
# - Boom Beach
# - Township
# - SimCity BuildIt
# - Talking Tom Cat 2

# %% [markdown]
# ### common factors between them
#
# - last updated in 2018
# - all of are free
# - rating is greater than 4.3

# %%
final_family_df
# Out:
#                                                App  rating_mass
# 192                                        Hay Day   45239337.0
# 807                                     Boom Beach   25162438.5
# 816                                       Township   20476058.2
# 994                                SimCity BuildIt   18983641.5
# 229                              Talking Tom Cat 2   13818256.4
# ...                                            ...          ...
# 1172                                   Mediabox CY          0.0
# 333   R Programming Language (Paperset 2) MCQ Quiz          0.0
# 1411                           EB Demo for Android          0.0
# 674                     Ain Arabic Kids Alif Ba ta          0.0
# 1002                                 CJ Auto école          0.0
#
# [1828 rows x 2 columns]

# %% [markdown]
# ### these are most famous , usable apps in Family category !!

# %%
final_family_df.reset_index(inplace=True)

# %%
final_family_df.to_csv('gaming_app.csv')

# %% [markdown]
# ## Over !!

# %% [markdown]
# ## Using KMeans algorithms

# %%
family_df.head()
# Out:
#                                                  App  Rating  Reviews  Type  \
# 0                       Jewels Crush- Match 3 Puzzle     4.4    14774  Free
# 1                                   Coloring & Learn     4.4    12753  Free
# 2                                            Mahjong     4.5    33983  Free
# 3  Super ABC! Learning games for kids! Preschool ...     4.6    20267  Free
# 4                                      Toy Pop Cubes     4.5     5761  Free
#
#   last_updated  total_install rating_age  Price_in_dollar  rating_mass
# 0         2018        1000000   Everyone              0.0      65005.6
# 1         2018        5000000   Everyone              0.0      56113.2
# 2         2018        5000000   Everyone              0.0     152923.5
# 3         2018        1000000   Everyone              0.0      93228.2
# 4         2018        1000000   Everyone              0.0      25924.5

# %%
family_df.shape
# Out:
# (1828, 9)

# %%
import numpy as np

# %%
family_df['app_id'] = np.arange(1,1829)
# Out:
# C:\Users\as\AppData\Local\Temp\ipykernel_8492\835772954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   family_df['app_id'] = np.arange(1,1829)

# %%
family_df
# Out:
#                                                     App  Rating  Reviews  \
# 0                          Jewels Crush- Match 3 Puzzle    4.40    14774
# 1                                      Coloring & Learn    4.40    12753
# 2                                               Mahjong    4.50    33983
# 3     Super ABC! Learning games for kids! Preschool ...    4.60    20267
# 4                                         Toy Pop Cubes    4.50     5761
# ...                                                 ...     ...      ...
# 1823                                            Poop FR    4.17        6
# 1824                                 Fr Agnel Ambarnath    4.20      117
# 1825                                      FR Calculator    4.00        7
# 1826                                   Sya9a Maroc - FR    4.50       38
# 1827                   Fr. Mike Schmitz Audio Teachings    5.00        4
#
#       Type last_updated  total_install rating_age  Price_in_dollar  \
# ...

# %%
cat_val = family_df.select_dtypes(include=object)

# %%
cat_val
# Out:
#                                                     App  Type last_updated  \
# 0                          Jewels Crush- Match 3 Puzzle  Free         2018
# 1                                      Coloring & Learn  Free         2018
# 2                                               Mahjong  Free         2018
# 3     Super ABC! Learning games for kids! Preschool ...  Free         2018
# 4                                         Toy Pop Cubes  Free         2018
# ...                                                 ...   ...          ...
# 1823                                            Poop FR  Free         2018
# 1824                                 Fr Agnel Ambarnath  Free         2018
# 1825                                      FR Calculator  Free         2017
# 1826                                   Sya9a Maroc - FR  Free         2017
# 1827                   Fr. Mike Schmitz Audio Teachings  Free         2018
#
#      rating_age
# 0      Everyone
# 1      Everyone
# ...

# %%
num_val= family_df.select_dtypes(exclude=object)

# %%
num_val
# Out:
#       Rating  Reviews  total_install  Price_in_dollar  rating_mass  app_id
# 0       4.40    14774        1000000              0.0     65005.60       1
# 1       4.40    12753        5000000              0.0     56113.20       2
# 2       4.50    33983        5000000              0.0    152923.50       3
# 3       4.60    20267        1000000              0.0     93228.20       4
# 4       4.50     5761        1000000              0.0     25924.50       5
# ...      ...      ...            ...              ...          ...     ...
# 1823    4.17        6             50              0.0        25.02    1824
# 1824    4.20      117           5000              0.0       491.40    1825
# 1825    4.00        7            500              0.0        28.00    1826
# 1826    4.50       38           5000              0.0       171.00    1827
# 1827    5.00        4            100              0.0        20.00    1828
#
# [1828 rows x 6 columns]

# %%
for i in range (family_df.shape[1]):
    print(i,family_df.columns[i])
# Out:
# 0 App
# 1 Rating
# 2 Reviews
# 3 Type
# 4 last_updated
# 5 total_install
# 6 rating_age
# 7 Price_in_dollar
# 8 rating_mass
# 9 app_id

# %%
cat_val.columns
# Out:
# Index(['App', 'Type', 'last_updated', 'rating_age'], dtype='object')

# %%
family_df.head()
# Out:
#                                                  App  Rating  Reviews  Type  \
# 0                       Jewels Crush- Match 3 Puzzle     4.4    14774  Free
# 1                                   Coloring & Learn     4.4    12753  Free
# 2                                            Mahjong     4.5    33983  Free
# 3  Super ABC! Learning games for kids! Preschool ...     4.6    20267  Free
# 4                                      Toy Pop Cubes     4.5     5761  Free
#
#   last_updated  total_install rating_age  Price_in_dollar  rating_mass  app_id
# 0         2018        1000000   Everyone              0.0      65005.6       1
# 1         2018        5000000   Everyone              0.0      56113.2       2
# 2         2018        5000000   Everyone              0.0     152923.5       3
# 3         2018        1000000   Everyone              0.0      93228.2       4
# 4         2018        1000000   Everyone              0.0      25924.5       5

# %%
# scaling of data

# %%
num_val.head()
# Out:
#    Rating  Reviews  total_install  Price_in_dollar  rating_mass  app_id
# 0     4.4    14774        1000000              0.0      65005.6       1
# 1     4.4    12753        5000000              0.0      56113.2       2
# 2     4.5    33983        5000000              0.0     152923.5       3
# 3     4.6    20267        1000000              0.0      93228.2       4
# 4     4.5     5761        1000000              0.0      25924.5       5

# %%
num_val.drop('app_id', axis=1, inplace=True)

# %%
num_val.head()
# Out:
#    Rating  Reviews  total_install  Price_in_dollar  rating_mass
# 0     4.4    14774        1000000              0.0      65005.6
# 1     4.4    12753        5000000              0.0      56113.2
# 2     4.5    33983        5000000              0.0     152923.5
# 3     4.6    20267        1000000              0.0      93228.2
# 4     4.5     5761        1000000              0.0      25924.5

# %% [markdown]
# ### Scaling of Data

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
std = StandardScaler()

# %%
min_max = MinMaxScaler()

# %%
scaled_num_val= std.fit_transform(num_val)

# %%
scaled_num_val
# Out:
# array([[ 0.45123826, -0.16315291, -0.15069187, -0.07020607, -0.1595507 ],
#        [ 0.45123826, -0.16831263,  0.27311937, -0.07020607, -0.16463404],
#        [ 0.65504414, -0.11411132,  0.27311937, -0.07020607, -0.10929248],
#        ...,
#        [-0.36398526, -0.20085385, -0.2565917 , -0.07020607, -0.19669512],
#        [ 0.65504414, -0.2007747 , -0.25611492, -0.07020607, -0.19661337],
#        [ 1.67407354, -0.2008615 , -0.25663408, -0.07020607, -0.19669969]])

# %%
scaled_num_val = pd.DataFrame(scaled_num_val)
scaled_num_val.columns= num_val.columns

# %%
scaled_num_val
# Out:
#         Rating   Reviews  total_install  Price_in_dollar  rating_mass
# 0     0.451238 -0.163153      -0.150692        -0.070206    -0.159551
# 1     0.451238 -0.168313       0.273119        -0.070206    -0.164634
# 2     0.655044 -0.114111       0.273119        -0.070206    -0.109292
# 3     0.858850 -0.149129      -0.150692        -0.070206    -0.143417
# 4     0.655044 -0.186164      -0.150692        -0.070206    -0.181891
# ...        ...       ...            ...              ...          ...
# 1823 -0.017515 -0.200856      -0.256639        -0.070206    -0.196697
# 1824  0.043626 -0.200573      -0.256115        -0.070206    -0.196430
# 1825 -0.363985 -0.200854      -0.256592        -0.070206    -0.196695
# 1826  0.655044 -0.200775      -0.256115        -0.070206    -0.196613
# 1827  1.674074 -0.200862      -0.256634        -0.070206    -0.196700
#
# [1828 rows x 5 columns]

# %%
num_val
# Out:
#       Rating  Reviews  total_install  Price_in_dollar  rating_mass
# 0       4.40    14774        1000000              0.0     65005.60
# 1       4.40    12753        5000000              0.0     56113.20
# 2       4.50    33983        5000000              0.0    152923.50
# 3       4.60    20267        1000000              0.0     93228.20
# 4       4.50     5761        1000000              0.0     25924.50
# ...      ...      ...            ...              ...          ...
# 1823    4.17        6             50              0.0        25.02
# 1824    4.20      117           5000              0.0       491.40
# 1825    4.00        7            500              0.0        28.00
# 1826    4.50       38           5000              0.0       171.00
# 1827    5.00        4            100              0.0        20.00
#
# [1828 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5,3))
# num_val.Price_in_dollar.plot(kind='kde')
sns.histplot(family_df.app_id)
# Out:
# <Axes: xlabel='app_id', ylabel='Count'>

# %%
sns.histplot(scaled_num_val.Rating)
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
plt.figure(figsize=(5,3))
sns.histplot(num_val.Rating)
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe= OneHotEncoder()

# %%
cat_val.drop('App', axis = 1, inplace=True)

# %%
cat_val.head(3)
# Out:
#    Type last_updated rating_age
# 0  Free         2018   Everyone
# 1  Free         2018   Everyone
# 2  Free         2018   Everyone

# %%
ohe_cat_val= ohe.fit(cat_val)

# %%
check_final = pd.concat([cat_val,scaled_num_val], axis=1)

# %%
check_final
# Out:
#       Type last_updated rating_age    Rating   Reviews  total_install  \
# 0     Free         2018   Everyone  0.451238 -0.163153      -0.150692
# 1     Free         2018   Everyone  0.451238 -0.168313       0.273119
# 2     Free         2018   Everyone  0.655044 -0.114111       0.273119
# 3     Free         2018   Everyone  0.858850 -0.149129      -0.150692
# 4     Free         2018   Everyone  0.655044 -0.186164      -0.150692
# ...    ...          ...        ...       ...       ...            ...
# 1823  Free         2018   Everyone -0.017515 -0.200856      -0.256639
# 1824  Free         2018   Everyone  0.043626 -0.200573      -0.256115
# 1825  Free         2017   Everyone -0.363985 -0.200854      -0.256592
# 1826  Free         2017   Everyone  0.655044 -0.200775      -0.256115
# 1827  Free         2018   Everyone  1.674074 -0.200862      -0.256634
#
#       Price_in_dollar  rating_mass
# 0           -0.070206    -0.159551
# 1           -0.070206    -0.164634
# ...

# %%
cat_val.columns
# Out:
# Index(['Type', 'last_updated', 'rating_age'], dtype='object')

# %%
scaled_num_val
# Out:
#         Rating   Reviews  total_install  Price_in_dollar  rating_mass
# 0     0.451238 -0.163153      -0.150692        -0.070206    -0.159551
# 1     0.451238 -0.168313       0.273119        -0.070206    -0.164634
# 2     0.655044 -0.114111       0.273119        -0.070206    -0.109292
# 3     0.858850 -0.149129      -0.150692        -0.070206    -0.143417
# 4     0.655044 -0.186164      -0.150692        -0.070206    -0.181891
# ...        ...       ...            ...              ...          ...
# 1823 -0.017515 -0.200856      -0.256639        -0.070206    -0.196697
# 1824  0.043626 -0.200573      -0.256115        -0.070206    -0.196430
# 1825 -0.363985 -0.200854      -0.256592        -0.070206    -0.196695
# 1826  0.655044 -0.200775      -0.256115        -0.070206    -0.196613
# 1827  1.674074 -0.200862      -0.256634        -0.070206    -0.196700
#
# [1828 rows x 5 columns]

# %%
scaled_num_val
# Out:
#         Rating   Reviews  total_install  Price_in_dollar  rating_mass
# 0     0.451238 -0.163153      -0.150692        -0.070206    -0.159551
# 1     0.451238 -0.168313       0.273119        -0.070206    -0.164634
# 2     0.655044 -0.114111       0.273119        -0.070206    -0.109292
# 3     0.858850 -0.149129      -0.150692        -0.070206    -0.143417
# 4     0.655044 -0.186164      -0.150692        -0.070206    -0.181891
# ...        ...       ...            ...              ...          ...
# 1823 -0.017515 -0.200856      -0.256639        -0.070206    -0.196697
# 1824  0.043626 -0.200573      -0.256115        -0.070206    -0.196430
# 1825 -0.363985 -0.200854      -0.256592        -0.070206    -0.196695
# 1826  0.655044 -0.200775      -0.256115        -0.070206    -0.196613
# 1827  1.674074 -0.200862      -0.256634        -0.070206    -0.196700
#
# [1828 rows x 5 columns]

# %% [markdown]
# ## Importing KMeans clustering

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3, max_iter=50)
kmeans.fit(scaled_num_val)
# Out:
# C:\Users\as\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(max_iter=50, n_clusters=3)

# %%
scaled_num_val.drop('rating_mass', axis =1 , inplace=True)

# %%
kmeans.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
family_df['label'] = kmeans.labels_
# Out:
# C:\Users\as\AppData\Local\Temp\ipykernel_8492\1541656760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   family_df['label'] = kmeans.labels_

# %%
family_df
# Out:
#                                                     App  Rating  Reviews  \
# 0                          Jewels Crush- Match 3 Puzzle    4.40    14774
# 1                                      Coloring & Learn    4.40    12753
# 2                                               Mahjong    4.50    33983
# 3     Super ABC! Learning games for kids! Preschool ...    4.60    20267
# 4                                         Toy Pop Cubes    4.50     5761
# ...                                                 ...     ...      ...
# 1823                                            Poop FR    4.17        6
# 1824                                 Fr Agnel Ambarnath    4.20      117
# 1825                                      FR Calculator    4.00        7
# 1826                                   Sya9a Maroc - FR    4.50       38
# 1827                   Fr. Mike Schmitz Audio Teachings    5.00        4
#
#       Type last_updated  total_install rating_age  Price_in_dollar  \
# ...

# %%
family_df.label.nunique()
# Out:
# 3

# %%
family_df.sort_values(by='rating_mass', ascending=False).head(5)
# Out:
#                    App  Rating   Reviews  Type last_updated  total_install  \
# 192            Hay Day     4.5  10053186  Free         2018      100000000
# 807         Boom Beach     4.5   5591653  Free         2018       50000000
# 816           Township     4.6   4451317  Free         2018       50000000
# 994    SimCity BuildIt     4.5   4218587  Free         2018       50000000
# 229  Talking Tom Cat 2     4.3   3213548  Free         2018      100000000
#
#     rating_age  Price_in_dollar  rating_mass  app_id  label
# 192   Everyone              0.0   45239337.0     193      2
# 807       Teen              0.0   25162438.5     808      2
# 816   Everyone              0.0   20476058.2     817      2
# 994       Teen              0.0   18983641.5     995      2
# 229       Teen              0.0   13818256.4     230      2

# %%
family_df.label.value_counts()
# Out:
# label
# 0    1780
# 2      44
# 1       4
# Name: count, dtype: int64

# %% [markdown]
# ## We can see that app which have label =2 are more usable , and total count of this app is 38.

# %%
top30_family= family_df[family_df.label==2].sort_values(by='rating_mass', ascending=False)

# %%
top30_family[['app_id', 'App']].head(5)
# Out:
#      app_id                App
# 192     193            Hay Day
# 807     808         Boom Beach
# 816     817           Township
# 994     995    SimCity BuildIt
# 229     230  Talking Tom Cat 2

# %% [markdown]
# ## Same insights I have found without using kmeans algorithm.

# %%
top30_family['Rank'] = np.arange(1,45)

# %%
final_application= top30_family[['Rank', 'app_id','App']]

# %%
final_application= final_application.reset_index(drop=True)

# %%
final_application
# Out:
#     Rank  app_id                                              App
# 0      1     193                                          Hay Day
# 1      2     808                                       Boom Beach
# 2      3     817                                         Township
# 3      4     995                                  SimCity BuildIt
# 4      5     230                                Talking Tom Cat 2
# 5      6     874                              Bubble Witch 2 Saga
# 6      7     404                             Angry Birds Epic RPG
# 7      8    1200                              MARVEL Future Fight
# 8      9     169                                        Minecraft
# 9     10     759                    Bitmoji – Your Personal Emoji
# 10    11    1020    Clash of Kings : The King Of Fighters version
# 11    12     182                      The Tribez: Build a Village
# 12    13     252                                  Talking Tom Cat
# ...
